# %% [markdown]
# # 30 Visual
#
# This notebook summarizes model results and graph-aware signals in a presentation format similar to the reference repository visual notebook.

# %%
from backend.app.services.graph_ml_service import GraphMLService
svc = GraphMLService()
svc.train_pipeline()
summary = svc.results_summary()
summary

# %%
svc.research_report()

# %%
svc.data_profile()

# %% [markdown]
# # 20 Modeling
#
# This notebook covers graph construction, feature engineering, model training, and account-level inference. It keeps the notebook-first format while reusing the production service layer.

# %%
from backend.app.services.graph_ml_service import GraphMLService
svc = GraphMLService()

# %%
artifacts = svc.train_pipeline(n_transactions=1200, n_accounts=220, fraud_rate=0.1, random_seed=7)
artifacts.metrics

# %%
svc.results_summary()

# %%
sample_account = svc.nodes_df.iloc[0]['account_id']
svc.predict_account(sample_account)
